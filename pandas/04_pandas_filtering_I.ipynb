# %%
import pandas as pd

# %%
df = pd.read_csv('../data/superstore_data.csv')

# %%
df[df['Year_Birth'] == 1989].head()
# Out:
#         Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 4     5371        1989  Graduation         Single  21474.0        1         0
# 136   6678        1989  Graduation       Together  31928.0        1         0
# 141   1031        1989    2n Cycle        Married  85710.0        0         0
# 331   4459        1989  Graduation         Single  30279.0        1         0
# 332  10642        1989  Graduation         Single  30279.0        1         0
#
#     Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 4      8/4/2014        0         6  ...               11                 0
# 136   3/28/2014        5        33  ...                4                 2
# 141    5/5/2013        5       600  ...               29                30
# 331  12/30/2012       13        10  ...                4                 4
# 332  12/30/2012       13        10  ...                4                 4
#
# ...

# %%
df[df.Education == 'Graduation'].head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
df[df.Kidhome > 0].head()
# Out:
#        Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 3    1386        1967  Graduation       Together  32474.0        1         1
# 4    5371        1989  Graduation         Single  21474.0        1         0
# 11   5642        1979      Master       Together  62499.0        1         0
# 15    837        1977  Graduation        Married  54809.0        1         1
# 16  10521        1977  Graduation        Married  54809.0        1         1
#
#    Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 3    11/5/2014        0        10  ...                0                 0
# 4     8/4/2014        0         6  ...               11                 0
# 11   9/12/2013        0       140  ...                0                13
# 15   11/9/2013        0        63  ...               13                13
# 16   11/9/2013        0        63  ...               13                13
#
# ...

# %%
df[(df.Kidhome != df.Teenhome)].size
# Out:
# 27016

# %%
df[df.Marital_Status.str.upper() == 'MARRIED'].head()
# Out:
#        Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 2   10476        1958  Graduation        Married  67267.0        0         1
# 6    4073        1954    2n Cycle        Married  63564.0        0         0
# 8    4047        1954         PhD        Married  65324.0        0         1
# 9    9477        1954         PhD        Married  65324.0        0         1
# 10   2079        1947    2n Cycle        Married  81044.0        0         0
#
#    Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 2   2014-05-13        0       134  ...               15                 2
# 6   2014-01-29        0       769  ...               15                34
# 8   2014-11-01        0       384  ...               21                32
# 9   2014-11-01        0       384  ...               21                32
# 10  2013-12-27        0       450  ...               73                98
#
# ...

# %%
income_gt_80k = df.Income > 80000
df[income_gt_80k].head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 10  2079        1947    2n Cycle        Married  81044.0        0         0
# 35  7962        1987         PhD         Single  95169.0        0         0
# 38  3725        1961         PhD         Single  84865.0        0         0
# 42  1524        1983    2n Cycle         Single  81698.0        0         0
#
#    Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   2014-06-16        0       189  ...              111               189
# 10  2013-12-27        0       450  ...               73                98
# 35  2013-09-10        1      1285  ...              106                20
# 38  2013-09-05        1      1248  ...               43                16
# 42  2013-01-03        1       709  ...               30               160
#
# ...

# %% [markdown]
# ### handling datetime columns

# %%
df['Dt_Customer'].head()
# Out:
# 0    6/16/2014
# 1    6/15/2014
# 2    5/13/2014
# 3    11/5/2014
# 4     8/4/2014
# Name: Dt_Customer, dtype: object

# %%
df['Dt_Customer'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2240 entries, 0 to 2239
# Series name: Dt_Customer
# Non-Null Count  Dtype
# --------------  -----
# 2240 non-null   object
# dtypes: object(1)
# memory usage: 17.6+ KB

# %%
pd.to_datetime(df['Dt_Customer'])
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-11-05
# 4      2014-08-04
#           ...
# 2235   2013-07-03
# 2236   2013-01-22
# 2237   2012-03-12
# 2238   2012-11-29
# 2239   2012-01-09
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
pd.to_datetime(df['Dt_Customer']).info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2240 entries, 0 to 2239
# Series name: Dt_Customer
# Non-Null Count  Dtype
# --------------  -----
# 2240 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 17.6 KB

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %% [markdown]
# ### Handling Boolean data

# %%
df['Complain'].value_counts()
# Out:
# 0    2219
# 1      21
# Name: Complain, dtype: int64

# %%
df['Complain'] = df['Complain'].astype('bool')

# %%
df['Complain'].value_counts()
# Out:
# False    2219
# True       21
# Name: Complain, dtype: int64

# %% [markdown]
# ### Handling Categorical data

# %%
df.Marital_Status.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2240 entries, 0 to 2239
# Series name: Marital_Status
# Non-Null Count  Dtype
# --------------  -----
# 2240 non-null   object
# dtypes: object(1)
# memory usage: 17.6+ KB

# %%
df.Marital_Status.value_counts()
# Out:
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: Marital_Status, dtype: int64

# %%
df['Marital_Status'] = df.Marital_Status.astype('category')

# %%
df['Marital_Status'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2240 entries, 0 to 2239
# Series name: Marital_Status
# Non-Null Count  Dtype
# --------------  -----
# 2240 non-null   category
# dtypes: category(1)
# memory usage: 2.7 KB

# %% [markdown]
# ### parse datetime column reading data

# %%
df_2 = pd.read_csv('../data/superstore_data.csv',parse_dates=['Dt_Customer'])
df_2.head(3)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0  2014-06-16        0       189  ...              111               189
# 1  2014-06-15        0       464  ...                7                 0
# 2  2014-05-13        0       134  ...               15                 2
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# ...

# %%
df[df.Dt_Customer > '2014-06-30'].head(3)
# Out:
#      Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 3  1386        1967  Graduation       Together  32474.0        1         1
# 4  5371        1989  Graduation         Single  21474.0        1         0
# 8  4047        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 3  2014-11-05        0        10  ...                0                 0
# 4  2014-08-04        0         6  ...               11                 0
# 8  2014-11-01        0       384  ...               21                32
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 3             0                  1                1                    0
# 4            34                  2                3                    1
# 8             5                  3                6                    2
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# ...
